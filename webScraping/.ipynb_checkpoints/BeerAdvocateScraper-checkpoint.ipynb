# %%
from pandas.core.strings import StringMethods as STR

from pattern.web import download
from pattern.web import URL, DOM, plaintext
import re
from pattern.web import NODE, TEXT, COMMENT, ELEMENT, DOCUMENT

# %%
html = download('http://www.beeradvocate.com/beer/style/', unicode=True)
dom = DOM(html)

# %%
def searchMe(string):
    print string

for link in dom.by_tag("a"):
    good_link = link.attrs.get("href","")
    if(re.match('/beer/style/\d+/$', good_link) != None):
        searchMe(abs(good_link, base='http://www.beeradvocate.com/'))
        count = count + 1
        

print count
# Out:
# http://www.beeradvocate.com/beer/style/128/
# http://www.beeradvocate.com/beer/style/19/
# http://www.beeradvocate.com/beer/style/175/
# http://www.beeradvocate.com/beer/style/99/
# http://www.beeradvocate.com/beer/style/73/
# http://www.beeradvocate.com/beer/style/94/
# http://www.beeradvocate.com/beer/style/140/
# http://www.beeradvocate.com/beer/style/157/
# http://www.beeradvocate.com/beer/style/116/
# http://www.beeradvocate.com/beer/style/97/
# http://www.beeradvocate.com/beer/style/93/
# http://www.beeradvocate.com/beer/style/159/
# http://www.beeradvocate.com/beer/style/158/
# http://www.beeradvocate.com/beer/style/78/
# http://www.beeradvocate.com/beer/style/171/
# http://www.beeradvocate.com/beer/style/130/
# http://www.beeradvocate.com/beer/style/163/
# http://www.beeradvocate.com/beer/style/6/
# http://www.beeradvocate.com/beer/style/72/
# http://www.beeradvocate.com/beer/style/12/
# http://www.beeradvocate.com/beer/style/60/
# http://www.beeradvocate.com/beer/style/119/
# ...
